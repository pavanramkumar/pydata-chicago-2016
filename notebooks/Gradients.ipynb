# %% [markdown]
# # Gradient vs. Newton step

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# /Users/pavanramkumar/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def simpleaxis(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    ax.tick_params(labelsize=14)

# %% [markdown]
# ## Consider the function $f(x) = x^2$

# %%
def f(x):
    return x ** 2

# %% [markdown]
# ### For $f(x) = x^2$, the gradient function $f'(x) = 2x$

# %%
def dfdx(x):
    return 2.0 * x

def update(x0, learning_rate):
    return x0 - learning_rate * dfdx(x0)

# %% [markdown]
# ### Let's visualize it

# %%
def display_f(x_range=[-1, 1], y_lim=[-0.1, 0.4], xc=None, tc=0):
    x = np.linspace(x_range[0], x_range[1], 100)
    plt.figure(figsize=(7,6))
    ax = plt.subplot(111)
    simpleaxis(ax)
    plt.plot(x, f(x), 'k', lw=3)
    if xc is not None:
        plt.plot(xc, f(xc), 'g*', lw=3, ms=12)
        plt.plot(x, f(xc) + dfdx(xc) * (x - xc), 'g--', lw=3)
        plt.title('$t = %d$' % tc, fontsize=18)
    plt.ylim([y_lim[0], y_lim[1]])
    plt.show()

# %%
display_f()

# %% [markdown]
# ### Let's consider the starting point as $x_0 = -0.25$.

# %%
x0 = -0.25
display_f(xc=x0, tc=0)

# %% [markdown]
# ### Assume the learning rate $\zeta = 0.1$

# %%
learning_rate = 0.1

# %% [markdown]
# ### Let's take one step in that direction

# %%
x1 = update(x0, learning_rate)
display_f(xc=x1, tc=1)

# %% [markdown]
# ### 5 steps

# %%
x_current = x0
maxiter = 5

for i in range(maxiter):
    x_next = update(x_current, learning_rate)
    x_current = x_next

display_f(xc=x_current, tc=maxiter)

# %% [markdown]
# ### 15 steps

# %%
x_current = x0
maxiter = 15

for i in range(maxiter):
    x_next = update(x_current, learning_rate)
    x_current = x_next

display_f(xc=x_current, tc=maxiter)

# %% [markdown]
# ### 50 steps

# %%
x_current = x0
maxiter = 50

for i in range(maxiter):
    x_next = update(x_current, learning_rate)
    x_current = x_next

display_f(xc=x_current, tc=maxiter)
